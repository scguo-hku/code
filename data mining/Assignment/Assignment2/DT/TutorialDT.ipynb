# %%
import sys
# !{sys.executable} -m pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.16-py2.py3-none-any.whl (19 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.16

# %%
# !{sys.executable} -m pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from pydot) (2.4.7)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2

# %%
#see also http://scikit-learn.org/stable/modules/tree.html
from sklearn import tree
from sklearn.datasets import load_iris
import pydot
import numpy as np
import random
from numpy.random import RandomState
from scipy import stats
import math
import graphviz


iris=load_iris()


#iris.data it contains the training data
#iris.target it contains the training class (rows correspond)
clf = tree.DecisionTreeClassifier(criterion='gini')
clf = clf.fit(iris.data, iris.target)


#to visualize the decision tree
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)  


graphv = graphviz.Source(dot_data)  


#print the decision tree in a pdf file
#from sklearn.externals.six import StringIO
from six import StringIO
import pydot
import graphviz

import pydot
dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data, feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True  
                    )
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph[0].write_pdf("data mining/Assignment/Assignment2/DT/irisDefault.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/site-packages/pydot/core.py:1851, in Dot.create(self, prog, format, encoding)
#    1850 try:
# -> 1851     stdout_data, stderr_data, process = call_graphviz(
#    1852         program=prog,
#    1853         arguments=arguments,
#    1854         working_dir=tmp_dir,
#    1855     )
#    1856 except OSError as e:
#
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/site-packages/pydot/core.py:211, in call_graphviz(program, arguments, working_dir, **kwargs)
#     209 program_with_args = [program] + arguments
# --> 211 process = subprocess.Popen(
#     212     program_with_args,
#     213     env=env,
#     214     cwd=working_dir,
#     215     shell=False,
#     216     stderr=subprocess.PIPE,
#     217     stdout=subprocess.PIPE,
#     218     **kwargs,
#     219 )
#     220 stdout_data, stderr_data = process.communicate()
#
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 47
#      41 tree.export_graphviz(clf, out_file=dot_data, feature_names=iris.feature_names,
#      42                          class_names=iris.target_names,
#      43                          filled=True, rounded=True,
#      44                          special_characters=True
#      45                     )
#      46 graph = pydot.graph_from_dot_data(dot_data.getvalue())
# ---> 47 graph[0].write_pdf("data mining/Assignment/Assignment2/DT/irisDefault.pdf")
#
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/site-packages/pydot/core.py:166, in __generate_format_methods.<locals>.__write_method(self, path, f, prog, encoding)
#     164 def __write_method(self, path, f=frmt, prog=None, encoding=None):
#     165     """Refer to docstring of method `write`."""
# --> 166     self.write(path, format=f, prog=prog, encoding=encoding)
#
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/site-packages/pydot/core.py:1762, in Dot.write(self, path, prog, format, encoding)
#    1760         f.write(s)
#    1761 else:
# -> 1762     s = self.create(prog, format, encoding=encoding)
#    1763     with open(path, mode="wb") as f:
#    1764         f.write(s)
#
# File /opt/homebrew/anaconda3/envs/dm/lib/python3.11/site-packages/pydot/core.py:1860, in Dot.create(self, prog, format, encoding)
#    1858     args = list(e.args)
#    1859     args[1] = f'"{prog}" not found in path.'
# -> 1860     raise OSError(*args)
#    1861 else:
#    1862     raise
#
# FileNotFoundError: [Errno 2] "dot" not found in path.

# %%
graphv

# %%
print ("training errors:"+str((1-clf.score(iris.data,iris.target))))
# Out:
# training errors:0.0

# %%
print ("Number of nodes in the tree:" +str(clf.tree_.node_count))
# Out:
# Number of nodes in the tree:17

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']
