# %%
import pandas as pd
import yfinance as yf

# %%
ticker = 'btc-usd'

df = yf.download(ticker, start="2024-05-01", end="2024-11-01", interval="1h")
df.to_csv('btc-usd.csv')
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                         Adj Close         Close          High  \
# Ticker                          BTC-USD       BTC-USD       BTC-USD
# Datetime
# 2024-05-01 00:00:00+00:00  60205.000000  60205.000000  60763.929688
# 2024-05-01 01:00:00+00:00  60046.039062  60046.039062  60314.199219
# 2024-05-01 02:00:00+00:00  59856.140625  59856.140625  60091.367188
# 2024-05-01 03:00:00+00:00  60180.308594  60180.308594  60197.792969
# 2024-05-01 04:00:00+00:00  60200.472656  60200.472656  60255.406250
# ...                                 ...           ...           ...
# 2024-10-31 19:00:00+00:00  70151.484375  70151.484375  70682.960938
# 2024-10-31 20:00:00+00:00  69897.851562  69897.851562  70168.578125
# 2024-10-31 21:00:00+00:00  70377.335938  70377.335938  70423.695312
# 2024-10-31 22:00:00+00:00  70379.320312  70379.320312  70430.593750
# 2024-10-31 23:00:00+00:00  70241.578125  70241.578125  70522.460938
#
# ...
